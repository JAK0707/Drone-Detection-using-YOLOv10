# %%
# !python --version
# Out:
# Python 3.9.19

# %% [markdown]
# ### Download repo and installing required packages

# %%
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...

# %%
cd yolov10
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov10'
# C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\yolov10

# %%
# !pip install .
# Out:
# Processing c:\users\jak\downloads\yolov10-custom-object-detection-main\yolov10-custom-object-detection-main\yolov10
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=735242 sha256=186afa86eafed348957723a59fd4d070677e66ea017ca5568d7c32011a525965
#   Stored in directory: C:\Users\JAK\AppData\Local\Temp\pip-ephem-wheel-cache-a842fze6\wheels\ff\5a\bf\868aa8ddb5fe51d8fd22287232bf853bef21f66c6b19d23114
# Successfully built ultralytics
# ...
#   Attempting uninstall: ultralytics
#     Found existing installation: ultralytics 8.1.34
#     Uninstalling ultralytics-8.1.34:
#       Successfully uninstalled ultralytics-8.1.34
# ...

# %% [markdown]
# ### Downloading pretrained weights

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\weights\yolov10n.pt
# Downloaded C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\weights\yolov10s.pt
# Downloaded C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\weights\yolov10m.pt
# Downloaded C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\weights\yolov10b.pt
# Downloaded C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\weights\yolov10x.pt
# Downloaded C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\weights\yolov10l.pt

# %% [markdown]
# # Inference using pretrained model

# %%
pip install --upgrade matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1650'

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=../weights/yolov10n.pt source=../test_images/1.jpg
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.11.7 torch-2.3.1 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# YOLOv10n summary (fused): 285 layers, 2762608 parameters, 63840 gradients, 8.6 GFLOPs
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\JAK\anaconda3\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\Users\JAK\anaconda3\Lib\site-packages\ultralytics\cfg\__init__.py", line 594, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\JAK\anaconda3\Lib\site-packages\ultralytics\engine\model.py", line 441, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
import matplotlib
matplotlib.use('agg')  # or any other backend that is supported

# Now run your YOLO task
# !yolo task=detect mode=predict conf=0.25 save=True model=../weights/yolov10n.pt source=../test_images/1.jpg
# Out:
# Traceback (most recent call last):
#   File "C:\Users\JAK\anaconda3\envs\gputest\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\JAK\anaconda3\envs\gputest\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\JAK\anaconda3\envs\gputest\Scripts\yolo.exe\__main__.py", line 4, in <module>
#   File "C:\Users\JAK\anaconda3\envs\gputest\lib\site-packages\ultralytics\__init__.py", line 5, in <module>
#     from ultralytics.data.explorer.explorer import Explorer
#   File "C:\Users\JAK\anaconda3\envs\gputest\lib\site-packages\ultralytics\data\__init__.py", line 3, in <module>
#     from .base import BaseDataset
#   File "C:\Users\JAK\anaconda3\envs\gputest\lib\site-packages\ultralytics\data\base.py", line 17, in <module>
#     from ultralytics.utils import DEFAULT_CFG, LOCAL_RANK, LOGGER, NUM_THREADS, TQDM
# ...

# %% [markdown]
# # Train Custom Model

# %%
import torch

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1650'

# %%
# !yolo task=detect mode=train epochs=1 batch=16 plots=True model=weights/yolov10n.pt data=custom_data.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.2.32 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.11.7 torch-2.3.1 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %% [markdown]
# # Inference

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train3/weights/best.pt source=test_images_1/veh2.jpg
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.11.7 torch-2.3.1 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# YOLOv10n summary (fused): 285 layers, 2694806 parameters, 0 gradients, 8.2 GFLOPs
#
# image 1/1 C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\test_images_1\veh2.jpg: 512x640 1 Plate, 87.3ms
# Speed: 4.5ms preprocess, 87.3ms inference, 110.1ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs\detect\predict2
# ðŸ’¡ Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Inference on Video

# %%
# !yolo task=detect mode=predict conf=0.25 save=True model=runs/detect/train3/weights/yolov10n_best.pt source=drone.mp4
# Out:
# Ultralytics YOLOv8.1.34 ðŸš€ Python-3.11.7 torch-2.3.1 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# YOLOv10n summary (fused): 285 layers, 2694806 parameters, 0 gradients, 8.2 GFLOPs
#
# video 1/1 (frame 1/548) C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\drone.mp4: 384x640 3 drones, 94.0ms
# video 1/1 (frame 2/548) C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\drone.mp4: 384x640 3 drones, 15.2ms
# video 1/1 (frame 3/548) C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\drone.mp4: 384x640 3 drones, 14.5ms
# video 1/1 (frame 4/548) C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\drone.mp4: 384x640 2 drones, 14.2ms
# video 1/1 (frame 5/548) C:\Users\JAK\Downloads\YOLOv10-Custom-Object-Detection-main\YOLOv10-Custom-Object-Detection-main\drone.mp4: 384x640 2 drones, 18.6ms
# ...

# %%
pip install supervision
# Out:
# ...
#   Using cached supervision-0.21.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached opencv_python_headless-4.10.0.82-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
# Using cached supervision-0.21.0-py3-none-any.whl (123 kB)
# Using cached opencv_python_headless-4.10.0.82-cp37-abi3-win_amd64.whl (38.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce GTX 1650'

# %%
pip install --upgrade opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
from ultralytics import YOLOv10
import supervision as sv

# Load YOLOv5 model
model_path = "C:/Users/JAK/Downloads/YOLOv10-Custom-Object-Detection-main/YOLOv10-Custom-Object-Detection-main/runs/detect/train3/weights/yolov10n_best.pt"  # Update with your actual path
model = YOLOv10(model_path)

# Create bounding box and label annotators
bounding_box_annotator = sv.BoundingBoxAnnotator()
label_annotator = sv.LabelAnnotator()

cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Unable to access webcam")
    exit()

while True:
    ret, frame = cap.read()

    if not ret:
        print("Failed to capture frame")
        break

    # Perform inference
    results = model(frame)[0]
    detections = sv.Detections.from_ultralytics(results)

    # Annotate image with bounding boxes and labels
    annotated_image = bounding_box_annotator.annotate(scene=frame, detections=detections)
    annotated_image = label_annotator.annotate(scene=annotated_image, detections=detections)

    # Display annotated image
    cv2.imshow('Webcam', annotated_image)

    # Exit on 'Esc' key press
    key = cv2.waitKey(1)
    if key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Failed to capture frame
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 43
#      40         break
#      42 cap.release()
# ---> 43 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1295: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvDestroyAllWindows'

# %%
import cv2

# Open a video capture
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open video capture.")
else:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Failed to capture image")
            break
        
        # Display the resulting frame
        cv2.imshow('Frame', frame)
        
        # Break the loop on 'q' key press
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    # When everything done, release the capture
    cap.release()

    # Use destroyAllWindows only if you need to close windows
    try:
        cv2.destroyAllWindows()
    except Exception as e:
        print(f"Exception occurred while destroying windows: {e}")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 16
#      13     break
#      15 # Display the resulting frame
# ---> 16 cv2.imshow('Frame', frame)
#      18 # Break the loop on 'q' key press
#      19 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# File ~\anaconda3\Lib\site-packages\ultralytics\utils\patches.py:56, in imshow(winname, mat)
#      48 def imshow(winname: str, mat: np.ndarray):
#      49     """
#      50     Displays an image in the specified window.
#      51
#    (...)
#      54         mat (np.ndarray): Image to be shown.
#      55     """
# ---> 56     _imshow(winname.encode("unicode_escape").decode(), mat)
#
# ...

# %%
import cv2

# Open a connection to the webcam (0 is the default camera)
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not open webcam.")
else:
    print("Press 'q' to close the window")

# Loop to continuously get frames
while True:
    ret, frame = cap.read()
    if not ret:
        print("Error: Could not read frame.")
        break

    # Display the resulting frame
    cv2.imshow('Webcam', frame)

    # Press 'q' on the keyboard to exit the loop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything is done, release the capture and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to close the window
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 19
#      16     break
#      18 # Display the resulting frame
# ---> 19 cv2.imshow('Webcam', frame)
#      21 # Press 'q' on the keyboard to exit the loop
#      22 if cv2.waitKey(1) & 0xFF == ord('q'):
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
